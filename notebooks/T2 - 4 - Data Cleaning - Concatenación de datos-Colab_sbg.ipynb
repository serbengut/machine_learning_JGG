# %% [markdown]
# <a href="https://colab.research.google.com/github/joanby/python-ml-course/blob/Collab---v-3.8/notebooks/T2%20-%204%20-%20Data%20Cleaning%20-%20Concatenaci%C3%B3n%20de%20datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Concatenar y apendizar data sets

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## El ejemplo del vino blanco y el vino tinto

# %% [markdown]
# Data Set Information:
#
# These data are the results of a chemical analysis of wines grown in the same region in Italy but derived from three different cultivars. The analysis determined the quantities of 13 constituents found in each of the three types of wines.
#
# I think that the initial data set had around 30 variables, but for some reason I only have the 13 dimensional version. I had a list of what the 30 or so variables were, but a.) I lost it, and b.), I would not know which 13 variables are included in the set.
#
# The attributes are (dontated by Riccardo Leardi, riclea '@' anchem.unige.it )
#
# 1. Alcohol
# 2. Malic acid
# 3. Ash
# 4. Alcalinity of ash
# 5. Magnesium
# 6. Total phenols
# 7. Flavanoids
# 8. Nonflavanoid phenols
# 9. Proanthocyanins
# 10. Color intensity
# 11. Hue
# 12. OD280/OD315 of diluted wines
# 13. Proline
#
# In a classification context, this is a well posed problem with "well behaved" class structures. A good data set for first testing of a new classifier, but not very challenging.
#
#
# Attribute Information:
#
# All attributes are continuous
#
# No statistics available, but suggest to standardise variables for certain uses (e.g. for us with classifiers which are NOT scale invariant)
#
# NOTE: 1st attribute is class identifier (1-3)

# %%
import pandas as pd

# %%
red_wine = pd.read_csv("/content/drive/MyDrive/Python Machine Learning JGG/datasets/wine/winequality-red.csv", sep=";")
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
red_wine.columns.values
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %%
red_wine.shape
# Out:
# (1599, 12)

# %%
white_wine = pd.read_csv("/content/drive/MyDrive/Python Machine Learning JGG/datasets/wine/winequality-white.csv", sep = ";")
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
white_wine.columns.values
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %%
white_wine.shape
# Out:
# (4898, 12)

# %% [markdown]
# En python, tenemos dos tipos de ejes,
# * axis = 0 denota el eje horizontal
# * axis = 1 denota el eje vertical

# %%
wine_data = pd.concat([red_wine, white_wine], axis = 0) # coloca primero el dataset red y luego debajo el blanco

# %%
wine_data.shape
# Out:
# (6497, 12)

# %%
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
data1 = wine_data.head(10)
data2 = wine_data[300:310]
data3 = wine_data.tail(10)

# %%
wine_scramble = pd.concat([data1, data2, data3], axis = 0)

# %%
wine_scramble
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00            1.90      0.076
# 1               7.8             0.880         0.00            2.60      0.098
# 2               7.8             0.760         0.04            2.30      0.092
# 3              11.2             0.280         0.56            1.90      0.075
# 4               7.4             0.700         0.00            1.90      0.076
# 5               7.4             0.660         0.00            1.80      0.075
# 6               7.9             0.600         0.06            1.60      0.069
# 7               7.3             0.650         0.00            1.20      0.065
# 8               7.8             0.580         0.02            2.00      0.073
# 9               7.5             0.500         0.36            6.10      0.071
# 300             7.5             0.530         0.06            2.60      0.086
# 301            11.1             0.180         0.48            1.50      0.068
# 302             8.3             0.705         0.12            2.60      0.092
# 303             7.4             0.670         0.12            1.60      0.186
# 304             8.4             0.650         0.60            2.10      0.112
# 305            10.3             0.530         0.48            2.50      0.063
# 306             7.6             0.620         0.32            2.20      0.082
# 307            10.3             0.410         0.42            2.40      0.213
# 308            10.3             0.430         0.44            2.40      0.214
# 309             7.4             0.290         0.38            1.70      0.062
# 4888            6.8             0.220         0.36            1.20      0.052
# 4889            4.9             0.235         0.27           11.75      0.030
# 4890            6.1             0.340         0.29            2.20      0.036
# 4891            5.7             0.210         0.32            0.90      0.038
# 4892            6.5             0.230         0.38            1.30      0.032
# 4893            6.2             0.210         0.29            1.60      0.039
# 4894            6.6             0.320         0.36            8.00      0.047
# 4895            6.5             0.240         0.19            1.20      0.041
# 4896            5.5             0.290         0.30            1.10      0.022
# 4897            6.0             0.210         0.38            0.80      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 5                    13.0                  40.0  0.99780  3.51       0.56
# 6                    15.0                  59.0  0.99640  3.30       0.46
# 7                    15.0                  21.0  0.99460  3.39       0.47
# 8                     9.0                  18.0  0.99680  3.36       0.57
# 9                    17.0                 102.0  0.99780  3.35       0.80
# 300                  20.0                  44.0  0.99650  3.38       0.59
# 301                   7.0                  15.0  0.99730  3.22       0.64
# 302                  12.0                  28.0  0.99940  3.51       0.72
# 303                   5.0                  21.0  0.99600  3.39       0.54
# 304                  12.0                  90.0  0.99730  3.20       0.52
# 305                   6.0                  25.0  0.99980  3.12       0.59
# 306                   7.0                  54.0  0.99660  3.36       0.52
# 307                   6.0                  14.0  0.99940  3.19       0.62
# 308                   5.0                  12.0  0.99940  3.19       0.63
# 309                   9.0                  30.0  0.99680  3.41       0.53
# 4888                 38.0                 127.0  0.99330  3.04       0.54
# 4889                 34.0                 118.0  0.99540  3.07       0.50
# 4890                 25.0                 100.0  0.98938  3.06       0.44
# 4891                 38.0                 121.0  0.99074  3.24       0.46
# 4892                 29.0                 112.0  0.99298  3.29       0.54
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# 5         9.4        5
# 6         9.4        5
# 7        10.0        7
# 8         9.5        7
# 9        10.5        5
# 300      10.7        6
# 301      10.1        6
# 302      10.0        5
# 303       9.5        5
# 304       9.2        5
# 305       9.3        6
# 306       9.4        5
# 307       9.5        6
# 308       9.5        6
# 309       9.5        6
# 4888      9.2        5
# 4889      9.4        6
# 4890     11.8        6
# 4891     10.6        6
# 4892      9.7        5
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6

# %%
wine_scramble = pd.concat([data2, data1, data3], axis = 0)
wine_scramble
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 300             7.5             0.530         0.06            2.60      0.086
# 301            11.1             0.180         0.48            1.50      0.068
# 302             8.3             0.705         0.12            2.60      0.092
# 303             7.4             0.670         0.12            1.60      0.186
# 304             8.4             0.650         0.60            2.10      0.112
# 305            10.3             0.530         0.48            2.50      0.063
# 306             7.6             0.620         0.32            2.20      0.082
# 307            10.3             0.410         0.42            2.40      0.213
# 308            10.3             0.430         0.44            2.40      0.214
# 309             7.4             0.290         0.38            1.70      0.062
# 0               7.4             0.700         0.00            1.90      0.076
# 1               7.8             0.880         0.00            2.60      0.098
# 2               7.8             0.760         0.04            2.30      0.092
# 3              11.2             0.280         0.56            1.90      0.075
# 4               7.4             0.700         0.00            1.90      0.076
# 5               7.4             0.660         0.00            1.80      0.075
# 6               7.9             0.600         0.06            1.60      0.069
# 7               7.3             0.650         0.00            1.20      0.065
# 8               7.8             0.580         0.02            2.00      0.073
# 9               7.5             0.500         0.36            6.10      0.071
# 4888            6.8             0.220         0.36            1.20      0.052
# 4889            4.9             0.235         0.27           11.75      0.030
# 4890            6.1             0.340         0.29            2.20      0.036
# 4891            5.7             0.210         0.32            0.90      0.038
# 4892            6.5             0.230         0.38            1.30      0.032
# 4893            6.2             0.210         0.29            1.60      0.039
# 4894            6.6             0.320         0.36            8.00      0.047
# 4895            6.5             0.240         0.19            1.20      0.041
# 4896            5.5             0.290         0.30            1.10      0.022
# 4897            6.0             0.210         0.38            0.80      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 300                  20.0                  44.0  0.99650  3.38       0.59
# 301                   7.0                  15.0  0.99730  3.22       0.64
# 302                  12.0                  28.0  0.99940  3.51       0.72
# 303                   5.0                  21.0  0.99600  3.39       0.54
# 304                  12.0                  90.0  0.99730  3.20       0.52
# 305                   6.0                  25.0  0.99980  3.12       0.59
# 306                   7.0                  54.0  0.99660  3.36       0.52
# 307                   6.0                  14.0  0.99940  3.19       0.62
# 308                   5.0                  12.0  0.99940  3.19       0.63
# 309                   9.0                  30.0  0.99680  3.41       0.53
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 5                    13.0                  40.0  0.99780  3.51       0.56
# 6                    15.0                  59.0  0.99640  3.30       0.46
# 7                    15.0                  21.0  0.99460  3.39       0.47
# 8                     9.0                  18.0  0.99680  3.36       0.57
# 9                    17.0                 102.0  0.99780  3.35       0.80
# 4888                 38.0                 127.0  0.99330  3.04       0.54
# 4889                 34.0                 118.0  0.99540  3.07       0.50
# 4890                 25.0                 100.0  0.98938  3.06       0.44
# 4891                 38.0                 121.0  0.99074  3.24       0.46
# 4892                 29.0                 112.0  0.99298  3.29       0.54
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 300      10.7        6
# 301      10.1        6
# 302      10.0        5
# 303       9.5        5
# 304       9.2        5
# 305       9.3        6
# 306       9.4        5
# 307       9.5        6
# 308       9.5        6
# 309       9.5        6
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# 5         9.4        5
# 6         9.4        5
# 7        10.0        7
# 8         9.5        7
# 9        10.5        5
# 4888      9.2        5
# 4889      9.4        6
# 4890     11.8        6
# 4891     10.6        6
# 4892      9.7        5
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6

# %% [markdown]
# ## Datos distribuidos

# %%
# cargar cientos de csv

# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/Python Machine Learning JGG/datasets/distributed-data/001.csv")
data.head()
# Out:
#          Date  sulfate  nitrate  ID
# 0  2003-01-01      NaN      NaN   1
# 1  2003-01-02      NaN      NaN   1
# 2  2003-01-03      NaN      NaN   1
# 3  2003-01-04      NaN      NaN   1
# 4  2003-01-05      NaN      NaN   1

# %%
data.shape
# Out:
# (1461, 4)

# %% [markdown]
# * Importar el primer fichero
# * Hacemos un bucle para ir recorriendo todos y cada uno de los ficheros.
#     * Importante tener una consistencia en el nombre de los ficheros
#     * Importamos los ficheros uno a uno
#     * Cada uno de ellos debe apendizarse (añadirse al final) del primer fichero que ya habíamos cargado
# * Repetimos el bucle hasta que no queden ficheros

# %%
#carga de cientos de csv
filepath = "/content/drive/MyDrive/Python Machine Learning JGG/datasets/distributed-data/"

data = pd.read_csv(filepath+"001.csv")
final_length = len(data)

for i in range(2,333): # hay 332 csv. el primero ya lo tenemos cargado y el último que ponemos (333) python no lo reconoce.
    if i < 10:
        filename = "00" + str(i)
    if 10 <= i < 100:
        filename = "0" + str(i)
    if i >= 100:
        filename = str(i)
    file = filepath + filename + ".csv"
    
    temp_data = pd.read_csv(file)
    final_length += len(temp_data)
    
    data = pd.concat([data, temp_data], axis = 0) # concatenamos el data original del primer csv, con los otros 331 que acabo de cargar

# %%
data.shape
# Out:
# (772087, 4)

# %%
data.tail()
# Out:
#            Date  sulfate  nitrate   ID
# 726  2004-12-27      NaN      NaN  332
# 727  2004-12-28      NaN      NaN  332
# 728  2004-12-29      NaN      NaN  332
# 729  2004-12-30      NaN      NaN  332
# 730  2004-12-31      NaN      NaN  332

# %%
data.head()
# Out:
#          Date  sulfate  nitrate  ID
# 0  2003-01-01      NaN      NaN   1
# 1  2003-01-02      NaN      NaN   1
# 2  2003-01-03      NaN      NaN   1
# 3  2003-01-04      NaN      NaN   1
# 4  2003-01-05      NaN      NaN   1

# %%
final_length == data.shape[0] #para confirmar que se han cargado todos los csv. si es True es correcto
# Out:
# True

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data.hist(["sulfate"])
# Out:
# array([[<Axes: title={'center': 'sulfate'}>]], dtype=object)

# %%
data.hist(["nitrate"])
# Out:
# array([[<Axes: title={'center': 'nitrate'}>]], dtype=object)

# %%
data.plot(kind="scatter", x="sulfate", y="nitrate")
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='sulfate', ylabel='nitrate'>

# %%
plt.hist(data["nitrate"], bins = 20, color="g")
# Out:
# (array([9.4045e+04, 1.3196e+04, 4.0140e+03, 1.5330e+03, 6.4400e+02,
#         3.8500e+02, 1.8400e+02, 1.2800e+02, 8.0000e+01, 4.1000e+01,
#         3.2000e+01, 2.3000e+01, 1.6000e+01, 8.0000e+00, 1.1000e+01,
#         5.0000e+00, 3.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([ 0.   ,  2.695,  5.39 ,  8.085, 10.78 , 13.475, 16.17 , 18.865,
#         21.56 , 24.255, 26.95 , 29.645, 32.34 , 35.035, 37.73 , 40.425,
#         43.12 , 45.815, 48.51 , 51.205, 53.9  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# # Joins de datasets

# %%
filepath = "/content/drive/MyDrive/Python Machine Learning JGG/datasets/athletes/"

# %%
### INCISO ###
# para saber el encoding de un archivo

data_prueba = open("/content/drive/MyDrive/Python Machine Learning JGG/datasets/athletes/Medals.csv","r")

# %%
data_prueba
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/Python Machine Learning JGG/datasets/athletes/Medals.csv' mode='r' encoding='UTF-8'>

# %%
data_prueba.close()
### FIN INCISO ###

# %%
data_main = pd.read_csv(filepath + "Medals.csv", encoding= "ISO-8859-1")

# %%
data_main.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4     Aleksey Nemov  24.0  2000            10/01/2000            2
#
#    Silver Medals  Bronze Medals  Total Medals
# 0              0              0             8
# 1              0              2             8
# 2              2              0             6
# 3              2              3             6
# 4              1              3             6

# %%
a = data_main["Athlete"].unique().tolist() # me da cuantos atletas unicos hay
len(a)
# Out:
# 6956

# %%
data_main.shape
# Out:
# (8618, 8)

# %%
data_country = pd.read_csv(filepath + "Athelete_Country_Map.csv", encoding = "ISO-8859-1")

# %%
data_country.head()
# Out:
#             Athlete        Country
# 0    Michael Phelps  United States
# 1  Natalie Coughlin  United States
# 2     Aleksey Nemov         Russia
# 3     Alicia Coutts      Australia
# 4    Missy Franklin  United States

# %%
data_country.shape
# Out:
# (6970, 2)

# %%
len(data_country) # en el datasets de Atleta - País, tengo 6970, son más que los atletas únicos que hay
# Out:
# 6970

# %%
data_country[data_country["Athlete"] == "Aleksandar Ciric"] # este ha participado con más de un pais.
# Out:
#                Athlete                Country
# 1029  Aleksandar Ciric                 Serbia
# 1086  Aleksandar Ciric  Serbia and Montenegro

# %%
data_sports = pd.read_csv(filepath + "Athelete_Sports_Map.csv", encoding="ISO-8859-1")

# %%
data_sports.head()
# Out:
#             Athlete       Sport
# 0    Michael Phelps    Swimming
# 1  Natalie Coughlin    Swimming
# 2     Aleksey Nemov  Gymnastics
# 3     Alicia Coutts    Swimming
# 4    Missy Franklin    Swimming

# %%
data_sports.shape
# Out:
# (6975, 2)

# %%
len(data_sports) # hay más deportistas ahora, quiere decir que un mismo atleta ha competido en más de un deporte
# Out:
# 6975

# %%
# la barra vertical | equivale a or
data_sports[(data_sports["Athlete"]=="Chen Jing") | 
            (data_sports["Athlete"]=="Richard Thompson") | 
            (data_sports["Athlete"]=="Matt Ryan")
           ]
# Out:
#                Athlete         Sport
# 528   Richard Thompson     Athletics
# 1308         Chen Jing    Volleyball
# 1419         Chen Jing  Table Tennis
# 2727         Matt Ryan        Rowing
# 5003         Matt Ryan    Equestrian
# 5691  Richard Thompson      Baseball

# %%
### ahora mismo tenemos 3 datasets:    data_main   data_country    data_sport
# data_main: con 6956 atletas distintos
# data_country: con 6970 atletas distintos (hay más porque hay atletas que han competido con más de un país)
# data_sport: con 6975 atletas distintos (hay más porque hay atletas que han competido en más de un deporte)

# %%
## conecto dos dataframes (main y country):

data_main_country2=pd.merge(left=data_main, right = data_country,left_on="Athlete", right_on="Athlete")

# %%
data_main_country2.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4  Natalie Coughlin  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8  United States
# 1              0              2             8  United States
# 2              2              0             6  United States
# 3              2              3             6  United States
# 4              2              1             5  United States

# %%
data_main_country2.shape # son más que las 8618 que había al ppio en el main
# Out:
# (8657, 9)

# %%
# esto da un error, y es que hay atletas que al haber competido con más de un pais, estamos duplicando sus medallas:
data_main_country2[data_main_country2["Athlete"]=="Aleksandar Ciric"]
# Out:
#                Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 1503  Aleksandar Ciric  30.0  2008            08/24/2008            0
# 1504  Aleksandar Ciric  30.0  2008            08/24/2008            0
# 1505  Aleksandar Ciric  26.0  2004            08/29/2004            0
# 1506  Aleksandar Ciric  26.0  2004            08/29/2004            0
# 1507  Aleksandar Ciric  22.0  2000            10/01/2000            0
# 1508  Aleksandar Ciric  22.0  2000            10/01/2000            0
#
#       Silver Medals  Bronze Medals  Total Medals                Country
# 1503              0              1             1                 Serbia
# 1504              0              1             1  Serbia and Montenegro
# 1505              1              0             1                 Serbia
# 1506              1              0             1  Serbia and Montenegro
# 1507              0              1             1                 Serbia
# 1508              0              1             1  Serbia and Montenegro

# %%
# para resolver esto, hay que eliminar los duplicados

# %%
data_country_dp = data_country.drop_duplicates(subset="Athlete")
# esto solo dejará solo un pais

# %%
len(data_country_dp)==len(a)
# Out:
# True

# %%
# ahora hacemos la unión de main y country

# %%
data_main_country = pd.merge(left = data_main, right = data_country_dp,
                            left_on="Athlete", right_on = "Athlete")

# %%
data_main_country.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4  Natalie Coughlin  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8  United States
# 1              0              2             8  United States
# 2              2              0             6  United States
# 3              2              3             6  United States
# 4              2              1             5  United States

# %%
data_main_country.shape
# Out:
# (8618, 9)

# %%
# ahora vemos que aleksandar ciric ya solo está con serbia
data_main_country[data_main_country["Athlete"] == "Aleksandar Ciric"]
# Out:
#                Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 1491  Aleksandar Ciric  30.0  2008            08/24/2008            0
# 1492  Aleksandar Ciric  26.0  2004            08/29/2004            0
# 1493  Aleksandar Ciric  22.0  2000            10/01/2000            0
#
#       Silver Medals  Bronze Medals  Total Medals Country
# 1491              0              1             1  Serbia
# 1492              1              0             1  Serbia
# 1493              0              1             1  Serbia

# %%
# ahora quito los duplicados de sport
data_sports_dp = data_sports.drop_duplicates(subset="Athlete")

# %%
len(data_sports_dp)==len(a)
# Out:
# True

# %%
data_final = pd.merge(left=data_main_country, right=data_sports_dp,
                     left_on="Athlete", right_on="Athlete")

# %%
data_final.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4  Natalie Coughlin  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country     Sport
# 0              0              0             8  United States  Swimming
# 1              0              2             8  United States  Swimming
# 2              2              0             6  United States  Swimming
# 3              2              3             6  United States  Swimming
# 4              2              1             5  United States  Swimming

# %%
data_final.shape
# Out:
# (8618, 10)

# %%
# lo guardo en un dataset nuevo llamado Medals_completo_by_sbg.csv
data_final.to_csv("/content/drive/MyDrive/Python Machine Learning JGG/datasets/athletes/Medals_completo_by_sbg.csv", header=True)

# %%
data_final[data_final["Country"] == "Spain"]
# Out:
#                          Athlete   Age  Year Closing Ceremony Date  \
# 279                Ona Carbonell  22.0  2012            08/12/2012
# 280               Andrea Fuentes  29.0  2012            08/12/2012
# 281               Andrea Fuentes  25.0  2008            08/24/2008
# 293                Gemma Mengual  31.0  2008            08/24/2008
# 311              Mireia Belmonte  21.0  2012            08/12/2012
# ...                          ...   ...   ...                   ...
# 7701             Berni Rodríguez  28.0  2008            08/24/2008
# 7702                 Ricky Rubio  17.0  2008            08/24/2008
# 8274  Francisco Javier Fernández  27.0  2004            08/29/2004
# 8320          Joan Lino Martínez  26.0  2004            08/29/2004
# 8507                 María Vascó  24.0  2000            10/01/2000
#
#       Gold Medals  Silver Medals  Bronze Medals  Total Medals Country  \
# 279             0              1              1             2   Spain
# 280             0              1              1             2   Spain
# 281             0              2              0             2   Spain
# 293             0              2              0             2   Spain
# 311             0              2              0             2   Spain
# ...           ...            ...            ...           ...     ...
# 7701            0              1              0             1   Spain
# 7702            0              1              0             1   Spain
# 8274            0              1              0             1   Spain
# 8320            0              0              1             1   Spain
# 8507            0              0              1             1   Spain
#
#                       Sport
# 279   Synchronized Swimming
# 280   Synchronized Swimming
# 281   Synchronized Swimming
# 293   Synchronized Swimming
# 311                Swimming
# ...                     ...
# 7701             Basketball
# 7702             Basketball
# 8274              Athletics
# 8320              Athletics
# 8507              Athletics
#
# [195 rows x 10 columns]

# %% [markdown]
# ## Tipos de Joins

# %%
from IPython.display import Image
import numpy as np

# %% [markdown]
# **Inner Join <= A (Left Join), B (Right Join) <= Outer Join**

# %%
# voy a eliminar algunos atletas de los datasets a modo de ejemplo para trabajar con los join

out_athletes = np.random.choice(data_main["Athlete"], size = 6, replace = False)

# %%
out_athletes
# Out:
# array(['Luigi Mastrangelo', 'Nathan Burgers', 'Alisa Camplin',
#        'Seth Wescott', 'Eric Lamaze', 'Moushaumi Robinson'], dtype=object)

# %%
# elimino, además de estos 6 de arriba, quito también a Phelps porque ha ganado muchas medallas.

# %%
data_country_dlt = data_country_dp[(~data_country_dp["Athlete"].isin(out_athletes)) & 
                                   (data_country_dp["Athlete"] != "Michael Phelps")]

data_sports_dlt = data_sports_dp[(~data_sports_dp["Athlete"].isin(out_athletes)) &
                                (data_sports_dp["Athlete"] != "Michael Phelps")]

data_main_dlt = data_main[(~data_main["Athlete"].isin(out_athletes)) & 
                         (data_main["Athlete"] != "Michael Phelps")]

# %%
len(data_country_dlt)
# Out:
# 6949

# %%
len(data_sports_dlt)
# Out:
# 6949

# %%
len(data_main_dlt)
# Out:
# 8605

# %% [markdown]
# ## Inner Join
# * Devuelve un data frame con las filas que tienen valor tanto en el primero como en el segundo data frame que estamos uniendo
# * El número de filas será igual al número de filas **comunes** que tengas ambos data sets
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#     * Ambos comparten 30 filas
#     * Entonces A Inner Join B tendrá 30 filas
# * En términos de teoría de conjuntos, se trata de la intersección de los dos conjuntos

# %%
Image(filename="/content/drive/MyDrive/Python Machine Learning JGG/notebooks/resources/inner-join.png")

# %%
# data_main contiene toda la info
# data_country_dlt le falta la info de 7 atletas

merged_inner = pd.merge(left = data_main, right = data_country_dlt,
                       how = "inner", left_on = "Athlete", right_on = "Athlete")

# %%
len(merged_inner)
# Out:
# 8605

# %%
merged_inner.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0  Natalie Coughlin  25.0  2008            08/24/2008            1
# 1  Natalie Coughlin  21.0  2004            08/29/2004            2
# 2  Natalie Coughlin  29.0  2012            08/12/2012            0
# 3     Aleksey Nemov  24.0  2000            10/01/2000            2
# 4     Alicia Coutts  24.0  2012            08/12/2012            1
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              2              3             6  United States
# 1              2              1             5  United States
# 2              0              1             1  United States
# 3              1              3             6         Russia
# 4              3              1             5      Australia

# %% [markdown]
# ## Left Join
# * Devuelve un data frame con las filas que tuvieran valor en el dataset de la izquierda, sin importar si tienen correspondencia en el de la derecha o no.
# * Las filas del data frame final que no correspondan a ninguna fila del data frame derecho, tendrán NAs en las columnas del data frame derecho.
# * El número de filas será igual al número de filas del data frame izquierdo
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#     * Entonces A Left Join B tendrá 60 filas
# * En términos de teoría de conjuntos, se trata del propio data set de la izquierda quien, además tiene la intersección en su interior.

# %%
Image(filename="/content/drive/MyDrive/Python Machine Learning JGG/notebooks/resources/left-join.png")

# %%
merged_left = pd.merge(left = data_main, right = data_country_dlt, 
                      how = "left", left_on = "Athlete", right_on = "Athlete")
len(merged_left)
# Out:
# 8618

# %%
merged_left.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4     Aleksey Nemov  24.0  2000            10/01/2000            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8            NaN
# 1              0              2             8            NaN
# 2              2              0             6            NaN
# 3              2              3             6  United States
# 4              1              3             6         Russia

# %% [markdown]
# ## Right Join
# * Devuelve un data frame con las filas que tuvieran valor en el dataset de la derecha, sin importar si tienen correspondencia en el de la izquierda o no.
# * Las filas del data frame final que no correspondan a ninguna fila del data frame izquierdo, tendrán NAs en las columnas del data frame izquierdo.
# * El número de filas será igual al número de filas del data frame derecho
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#     * Entonces A Right Join B tendrá 50 filas
# * En términos de teoría de conjuntos, se trata del propio data set de la derecha quien, además tiene la intersección en su interior.

# %%
Image(filename="/content/drive/MyDrive/Python Machine Learning JGG/notebooks/resources/right-join.png")

# %%
merged_right = pd.merge(left = data_main_dlt, right = data_country_dp,
                       how = "right", left_on = "Athlete", right_on = "Athlete")
len(merged_right)
# Out:
# 8612

# %%
merged_right.tail(10)
# Out:
#                    Athlete   Age    Year Closing Ceremony Date  Gold Medals  \
# 8602         Butch Johnson  45.0  2000.0            10/01/2000          0.0
# 8603        Kim Cheong-Tae  20.0  2000.0            10/01/2000          1.0
# 8604       Barbara Mensing  39.0  2000.0            10/01/2000          0.0
# 8605             O Gyo-Mun  28.0  2000.0            10/01/2000          1.0
# 8606        Cornelia Pfohl  29.0  2000.0            10/01/2000          0.0
# 8607      Olena Sadovnycha  32.0  2000.0            10/01/2000          0.0
# 8608      Kateryna Serdiuk  17.0  2000.0            10/01/2000          0.0
# 8609      Wietse van Alten  21.0  2000.0            10/01/2000          0.0
# 8610  Sandra Wagner-Sachse  31.0  2000.0            10/01/2000          0.0
# 8611             Rod White  23.0  2000.0            10/01/2000          0.0
#
#       Silver Medals  Bronze Medals  Total Medals        Country
# 8602            0.0            1.0           1.0  United States
# 8603            0.0            0.0           1.0    South Korea
# 8604            0.0            1.0           1.0        Germany
# 8605            0.0            0.0           1.0    South Korea
# 8606            0.0            1.0           1.0        Germany
# 8607            1.0            0.0           1.0        Ukraine
# 8608            1.0            0.0           1.0        Ukraine
# 8609            0.0            1.0           1.0    Netherlands
# 8610            0.0            1.0           1.0        Germany
# 8611            0.0            1.0           1.0  United States

# %% [markdown]
# ## Outer Join
# * Devuelve un data frame con todas las filas de ambos, reemplazando las ausencias de uno o de otro con NAs en la región específica..
# * Las filas del data frame final que no correspondan a ninguna fila del data frame derecho (o izquierdo), tendrán NAs en las columnas del data frame derecho (o izquierdo).
# * El número de filas será igual al máximo número de filas de ambos data frames
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#     * Ambos comparten 30 filas
#     * Entonces A Outer Join B tendrá 60 + 50 - 30 = 80 filas
# * En términos de teoría de conjuntos, se trata de la unión de conjuntos.

# %%
Image(filename="/content/drive/MyDrive/Python Machine Learning JGG/notebooks/resources/outer-join.png")

# %%
data_country_jb = data_country_dlt.append(
    {
        "Athlete": "Juan Gabriel Gomila",
        "Country": "España"
    },ignore_index = True
)
# Out:
# <ipython-input-116-e78cdea659c6>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_country_jb = data_country_dlt.append(

# %%
data_country_jb
# Out:
#                    Athlete        Country
# 0         Natalie Coughlin  United States
# 1            Aleksey Nemov         Russia
# 2            Alicia Coutts      Australia
# 3           Missy Franklin  United States
# 4              Ryan Lochte  United States
# ...                    ...            ...
# 6945      Kateryna Serdiuk        Ukraine
# 6946      Wietse van Alten    Netherlands
# 6947  Sandra Wagner-Sachse        Germany
# 6948             Rod White  United States
# 6949   Juan Gabriel Gomila         España
#
# [6950 rows x 2 columns]

# %%
merged_outer = pd.merge(left = data_main, right=data_country_jb,
                       how = "outer", left_on = "Athlete", right_on="Athlete")
len(merged_outer)
# Out:
# 8619

# %%
merged_outer.head()
# Out:
#             Athlete   Age    Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008.0            08/24/2008          8.0
# 1    Michael Phelps  19.0  2004.0            08/29/2004          6.0
# 2    Michael Phelps  27.0  2012.0            08/12/2012          4.0
# 3  Natalie Coughlin  25.0  2008.0            08/24/2008          1.0
# 4  Natalie Coughlin  21.0  2004.0            08/29/2004          2.0
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0            0.0            0.0           8.0            NaN
# 1            0.0            2.0           8.0            NaN
# 2            2.0            0.0           6.0            NaN
# 3            2.0            3.0           6.0  United States
# 4            2.0            1.0           5.0  United States

# %%
merged_outer.tail()
# Out:
#                    Athlete   Age    Year Closing Ceremony Date  Gold Medals  \
# 8614      Kateryna Serdiuk  17.0  2000.0            10/01/2000          0.0
# 8615      Wietse van Alten  21.0  2000.0            10/01/2000          0.0
# 8616  Sandra Wagner-Sachse  31.0  2000.0            10/01/2000          0.0
# 8617             Rod White  23.0  2000.0            10/01/2000          0.0
# 8618   Juan Gabriel Gomila   NaN     NaN                   NaN          NaN
#
#       Silver Medals  Bronze Medals  Total Medals        Country
# 8614            1.0            0.0           1.0        Ukraine
# 8615            0.0            1.0           1.0    Netherlands
# 8616            0.0            1.0           1.0        Germany
# 8617            0.0            1.0           1.0  United States
# 8618            NaN            NaN           NaN         España

# %%
len(data_main)
# Out:
# 8618

# %%
len(data_main_dlt)
# Out:
# 8605

# %%
len(data_country_dp)
# Out:
# 6956

# %%
len(data_country_dlt)
# Out:
# 6949

# %%
len(merged_inner)
# Out:
# 8605

# %%
len(merged_left)
# Out:
# 8618

# %%
len(merged_right)
# Out:
# 8612

# %%
len(merged_outer)
# Out:
# 8619
